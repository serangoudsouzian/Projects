# %%
! sudo apt install tesseract-ocr
! apt install libtesseract-dev
! pip install tesseract
! pip install Pillow
! pip install pytesseract
! apt install tesseract-ocr-script-armn
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libtesseract-dev is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr-script-armn is already the newest version (1:4.00~git30-7274cfa-1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.

# %%
import re
import cv2
import numpy as np
import pytesseract
from pytesseract import Output
from matplotlib import pyplot as plt

import shutil
import os
import random
try:
 from PIL import Image
except ImportError:
 import Image

# %%
# Mount drive
from google.colab import drive
drive.mount('/drive', force_remount=True)
# Out:
# Mounted at /drive

# %%
# get grayscale image
def get_grayscale(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# noise removal
def remove_noise(image):
    return cv2.medianBlur(image,5)

#thresholding
def thresholding(image):
    return cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

#dilation
def dilate(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.dilate(image, kernel, iterations = 1)

#erosion
def erode(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.erode(image, kernel, iterations = 1)

#opening - erosion followed by dilation
def opening(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)

#canny edge detection
def canny(image):
    return cv2.Canny(image, 100, 200)

# %%
# Plot original image

image = cv2.imread(f'/drive/My Drive/IS/OCRDialogue2.png')
b,g,r = cv2.split(image)
rgb_img = cv2.merge([r,g,b])
plt.imshow(rgb_img)
plt.title('ORIGINAL IMAGE')
plt.show()

# %%
! sudo apt-get install tesseract-ocr-hye
! tesseract --list-langs
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   tesseract-ocr-hye
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 1,191 kB of archives.
# After this operation, 3,479 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-hye all 1:4.00~git30-7274cfa-1.1 [1,191 kB]
# Fetched 1,191 kB in 1s (1,289 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# ...

# %%
#for i in range(1, 10):
! tesseract '/drive/My Drive/IS/images/paired/00''0''.arm.png' stdout -l hye+eng > '/drive/My Drive/IS/images/results/arm.res.00''0''.txt'
# Out:
# Error opening data file /usr/share/tesseract-ocr/4.00/tessdata/hye.traineddata
# Please make sure the TESSDATA_PREFIX environment variable is set to your "tessdata" directory.
# Failed loading language 'hye'
# Error, cannot read input file /drive/My Drive/IS/images/paired/000.arm.png: No such file or directory
# Error during processing.

# %%
! tesseract '/drive/My Drive/IS/images/paired/001.arm.png' stdout -l hye > '/drive/My Drive/IS/images/arm_results/arm.res.001.txt'
! tesseract '/drive/My Drive/IS/images/paired/002.arm.png' stdout -l hye > '/drive/My Drive/IS/images/arm_results/arm.res.002.txt'
! tesseract '/drive/My Drive/IS/images/paired/003.arm.png' stdout -l hye > '/drive/My Drive/IS/images/arm_results/arm.res.003.txt'
! tesseract '/drive/My Drive/IS/images/paired/004.arm.png' stdout -l hye > '/drive/My Drive/IS/images/arm_results/arm.res.004.txt'
! tesseract '/drive/My Drive/IS/images/paired/005.arm.png' stdout -l hye > '/drive/My Drive/IS/images/arm_results/arm.res.005.txt'
! tesseract '/drive/My Drive/IS/images/paired/006.arm.png' stdout -l hye > '/drive/My Drive/IS/images/arm_results/arm.res.006.txt'
! tesseract '/drive/My Drive/IS/images/paired/007.arm.png' stdout -l hye > '/drive/My Drive/IS/images/arm_results/arm.res.007.txt'
! tesseract '/drive/My Drive/IS/images/paired/008.arm.png' stdout -l hye > '/drive/My Drive/IS/images/arm_results/arm.res.008.txt'
! tesseract '/drive/My Drive/IS/images/paired/009.arm.png' stdout -l hye > '/drive/My Drive/IS/images/arm_results/arm.res.009.txt'
! tesseract '/drive/My Drive/IS/images/paired/010.arm.png' stdout -l hye > '/drive/My Drive/IS/images/arm_results/arm.res.010.txt'
! tesseract '/drive/My Drive/IS/images/paired/011.arm.png' stdout -l hye > '/drive/My Drive/IS/images/arm_results/arm.res.011.txt'
! tesseract '/drive/My Drive/IS/images/paired/012.arm.png' stdout -l hye > '/drive/My Drive/IS/images/arm_results/arm.res.012.txt'
! tesseract '/drive/My Drive/IS/images/paired/013.arm.png' stdout -l hye > '/drive/My Drive/IS/images/arm_results/arm.res.013.txt'
! tesseract '/drive/My Drive/IS/images/paired/014.arm.png' stdout -l hye > '/drive/My Drive/IS/images/arm_results/arm.res.014.txt'
! tesseract '/drive/My Drive/IS/images/paired/015.arm.png' stdout -l hye > '/drive/My Drive/IS/images/arm_results/arm.res.015.txt'
! tesseract '/drive/My Drive/IS/images/paired/016.arm.png' stdout -l hye > '/drive/My Drive/IS/images/arm_results/arm.res.016.txt'
! tesseract '/drive/My Drive/IS/images/paired/017.arm.png' stdout -l hye > '/drive/My Drive/IS/images/arm_results/arm.res.017.txt'
! tesseract '/drive/My Drive/IS/images/paired/018.arm.png' stdout -l hye > '/drive/My Drive/IS/images/arm_results/arm.res.018.txt'
! tesseract '/drive/My Drive/IS/images/paired/019.arm.png' stdout -l hye > '/drive/My Drive/IS/images/arm_results/arm.res.019.txt'
! tesseract '/drive/My Drive/IS/images/paired/020.arm.png' stdout -l hye > '/drive/My Drive/IS/images/arm_results/arm.res.020.txt'
! tesseract '/drive/My Drive/IS/images/paired/021.arm.png' stdout -l hye > '/drive/My Drive/IS/images/arm_results/arm.res.021.txt'
# Out:
# ...
# Estimating resolution as 525
# ...
# Estimating resolution as 526
# ...
# Estimating resolution as 530
# ...
# Estimating resolution as 533
# ...
# Estimating resolution as 531
# ...
# Estimating resolution as 522
# ...
# Estimating resolution as 536
# ...
# Estimating resolution as 528
# ...
# Estimating resolution as 532
# ...
# Estimating resolution as 519
# ...
# Estimating resolution as 531
# ...
# Estimating resolution as 533
# ...
# Estimating resolution as 533
# ...
# Estimating resolution as 535
# ...
# Estimating resolution as 528
# ...
# Estimating resolution as 566
# ...
# Estimating resolution as 536
# ...
# Estimating resolution as 534
# ...
# Estimating resolution as 563
# ...
# Estimating resolution as 523
# ...
# Estimating resolution as 444

# %%
! tesseract '/drive/My Drive/IS/images/paired/001.eng.png' stdout -l eng > '/drive/My Drive/IS/images/eng_results/eng.res.001.txt'
! tesseract '/drive/My Drive/IS/images/paired/002.eng.png' stdout -l eng > '/drive/My Drive/IS/images/eng_results/eng.res.002.txt'
! tesseract '/drive/My Drive/IS/images/paired/003.eng.png' stdout -l eng > '/drive/My Drive/IS/images/eng_results/eng.res.003.txt'
! tesseract '/drive/My Drive/IS/images/paired/004.eng.png' stdout -l eng > '/drive/My Drive/IS/images/eng_results/eng.res.004.txt'
! tesseract '/drive/My Drive/IS/images/paired/005.eng.png' stdout -l eng > '/drive/My Drive/IS/images/eng_results/eng.res.005.txt'
! tesseract '/drive/My Drive/IS/images/paired/006.eng.png' stdout -l eng > '/drive/My Drive/IS/images/eng_results/eng.res.006.txt'
! tesseract '/drive/My Drive/IS/images/paired/007.eng.png' stdout -l eng > '/drive/My Drive/IS/images/eng_results/eng.res.007.txt'
! tesseract '/drive/My Drive/IS/images/paired/008.eng.png' stdout -l eng > '/drive/My Drive/IS/images/eng_results/eng.res.008.txt'
! tesseract '/drive/My Drive/IS/images/paired/009.eng.png' stdout -l eng > '/drive/My Drive/IS/images/eng_results/eng.res.009.txt'
! tesseract '/drive/My Drive/IS/images/paired/010.eng.png' stdout -l eng > '/drive/My Drive/IS/images/eng_results/eng.res.010.txt'
! tesseract '/drive/My Drive/IS/images/paired/011.eng.png' stdout -l eng > '/drive/My Drive/IS/images/eng_results/eng.res.011.txt'
! tesseract '/drive/My Drive/IS/images/paired/012.eng.png' stdout -l eng > '/drive/My Drive/IS/images/eng_results/eng.res.012.txt'
! tesseract '/drive/My Drive/IS/images/paired/013.eng.png' stdout -l eng > '/drive/My Drive/IS/images/eng_results/eng.res.013.txt'
! tesseract '/drive/My Drive/IS/images/paired/014.eng.png' stdout -l eng > '/drive/My Drive/IS/images/eng_results/eng.res.014.txt'
! tesseract '/drive/My Drive/IS/images/paired/015.eng.png' stdout -l eng > '/drive/My Drive/IS/images/eng_results/eng.res.015.txt'
! tesseract '/drive/My Drive/IS/images/paired/016.eng.png' stdout -l eng > '/drive/My Drive/IS/images/eng_results/eng.res.016.txt'
! tesseract '/drive/My Drive/IS/images/paired/017.eng.png' stdout -l eng > '/drive/My Drive/IS/images/eng_results/eng.res.017.txt'
! tesseract '/drive/My Drive/IS/images/paired/018.eng.png' stdout -l eng > '/drive/My Drive/IS/images/eng_results/eng.res.018.txt'
! tesseract '/drive/My Drive/IS/images/paired/019.eng.png' stdout -l eng > '/drive/My Drive/IS/images/eng_results/eng.res.019.txt'
! tesseract '/drive/My Drive/IS/images/paired/020.eng.png' stdout -l eng > '/drive/My Drive/IS/images/eng_results/eng.res.020.txt'
! tesseract '/drive/My Drive/IS/images/paired/021.eng.png' stdout -l eng > '/drive/My Drive/IS/images/eng_results/eng.res.021.txt'
# Out:
# ...
# Estimating resolution as 573
# ...
# Estimating resolution as 577
# ...
# Estimating resolution as 583
# ...
# Estimating resolution as 587
# ...
# Estimating resolution as 579
# ...
# Estimating resolution as 544
# ...
# Estimating resolution as 581
# ...
# Estimating resolution as 581
# ...
# Estimating resolution as 571
# ...
# Estimating resolution as 505
# ...
# Estimating resolution as 576
# ...
# Estimating resolution as 586
# ...
# Estimating resolution as 543
# ...
# Estimating resolution as 585
# ...
# Estimating resolution as 569
# ...
# Estimating resolution as 584
# ...
# Estimating resolution as 565
# ...
# Estimating resolution as 580
# ...
# Estimating resolution as 582
# ...
# Estimating resolution as 581
# ...
# Estimating resolution as 489

# %%
! tesseract '/drive/My Drive/IS/OCRDialogue2.png' stdout -l hye+eng >> '/drive/My Drive/IS/TextOutputEngArm.txt'

# %%
! tesseract '/drive/My Drive/IS/OCRDialogue3.png' stdout -l hye+eng >> '/drive/My Drive/IS/TextOutputEngArm.txt'

# %%
def contains_armenian_chars(input_string):
    armenian_range = (0x0531, 0x058F)  # Armenian capital and small letters Unicode range

    for char in input_string:
        char_code = ord(char)
        if armenian_range[0] <= char_code <= armenian_range[1]:
            return True

    return False

# %%
f=open('/drive/My Drive/IS/TextOutput.txt','r')
file = f.read()

list=file.split("\n")
arm = []
counter = 0
for l in list:
  if contains_armenian_chars(l) == True:
    arm.append(l)
    print(str(counter) + l)
    counter=counter+1


del arm[10]
f.close()
# Out:
# 0. Բարեւ, Անի։
# 1. Բարեւ, Մճրի։ Դուն Հու Ի՞նչ կ'ընես.
# 2կ աշչլխառտի'ս։
# 3. Ոչ, Հայերէն կը սորվիմ։
# 4. Բայց դուն Հայերէն qfunku, չէ"
# 5. կր Հասկնամ, Քիչ մոն ալ մը fuouful,
# 6բայց չեմ գրեր ու չեմ կարդար:
# 7. Երկար է, բայց բնաւ դժուար չէ։
# 8: Բոլոր գիրերը կրնաս դրել:
# 9.Դեռ Բոլորը չեմ դիտեր:
# 10161 քօ10ո3 Հիօռ kider]
# 11. Ամէն օր Հայերէնի դաս ունիք:
# 12. N's, չաբաթը երկու անդամ:
# 13. կ'ուզես Քեզի Հարցեր տամ:
# 14. ինչո՞ւ չէ: Ubu ‘ing:
# 15ւ Աս Ի՞նչ է։
# 16Սս դասարան ։
# 17ի Հոս Ինչ կայ:
# 18. Սեղան մր, ասեղաններ ն աթոռներ:
# 19ղան մը, գրասեղաններ ներ
# 20Սեղանին վրալ ի՞նչ կալ"
# 21ի Գիրքեր A տետրակներ:
# 22. /ւրիչ Ի՞նչ կայ:
# 23. Մատիտներ, երկու գրիչ: ռետին մը
# 24ն. ուրիչ չատ բաներ:
# 25. Հոս ո՞վ կը նատի:
# 26. Ուսու ghee
# 27ւ իսկ Հո՞ն։
# 28. Հոն ուսանողները կը նատին:
# 29` Պատին վրայ (Ր նչ կայ:
# 30. Գրատախտակը A gunn նկարներ:
# 31. Ուրի՛շ։
# 32(Սոջե՞)
# 33. Ժամացոյց մբ:
# 34. Ապրի՛ս, լաւ աչակերտուծի ես:
# 351ԱԻ ՊԱՏԱՍԽԱՆ ՄԸ
# ...

# %%
f=open('/drive/My Drive/IS/Tesseract_Correct.txt','r')
file = f.read()

arm_correct=file.split("\n")



print(len(arm_correct))
f.close()
# Out:
# 50

# %%
! pip install python-Levenshtein

# %%
from Levenshtein import distance

f=open('/drive/My Drive/IS/uncorrected/src2_english/002.txt','r')
file = f.read()

ocr_list =file.split("\n")

f=open('/drive/My Drive/IS/corrected/tgt_armenian/002.txt','r')
file = f.read()

ground_list =file.split("\n")
lev_distance = 0
for i in range(0,len(ocr_list)):
  ground_value = ground_list[i]
  #print(type(ground_value))
  ocr_value=ocr_list[i]
  #print(type(ocr_value))

  lev_distance += (distance(ground_value, ocr_value))
print(lev_distance)
# Out:
# 166

# %%
# Preprocess image

gray = get_grayscale(image)
thresh = thresholding(gray)
opening = opening(gray)
canny = canny(gray)
noise = remove_noise(gray)
images = {'gray': gray,
          'thresh': thresh,
          'opening': opening,
          'noise': noise}

# %%
# Plot images after preprocessing

fig = plt.figure(figsize=(13,10))
ax = []

rows = 1
columns = 4
keys = list(images.keys())
for i in range(rows*columns):
    ax.append( fig.add_subplot(rows, columns, i+1) )
    ax[-1].set_title(keys[i])
    plt.imshow(images[keys[i]], cmap='gray')
